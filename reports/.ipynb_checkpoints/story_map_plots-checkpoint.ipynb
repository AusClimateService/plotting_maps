# %% [markdown]
# Hi Gen
#
#
# I work in the ACS's communications area.
#
# I am hoping you might be able to assist with a rather urgent task this week. We are seeking a series of high-res hazard data maps – the same that were used in the Future Hazard report for a story map being put together.
#
#
#
# We have a few specifics we're hoping you may be able to create for us or steer us in the right direction.
#
# All four of:
#
# *  Severe or extreme heatwave days map
# *  Time spent in drought maps
# *  Changes in days of sever fire danger maps
# *  Marine heatwave duration maps
# *  Maximum Daily runoff maps
# *  Coastal Flood extent maps
# *  Changes in extreme coastal erosion maps
# *  Tropical Cyclone frequency maps
#
# All with no ACS logo but a copyright ACS line included. We also need the scale (which is currently running along the bottom) on the side on each of them.
#
#
# I have attached the Risk Assessment colour hues, if it would be possible to apply this also.
#
#
#
# I realise it is a fairly big ask. If you think it could be a problem, please let me know.
#
#
#
# Free to chat.
#
#
#
# Angela
#
#
# Apologies, Gen, we also were hoping for no caption on any of the files.

# %%
cd /g/data/mn51/users/gt3409/plotting_maps/
# Out:
# /g/data/mn51/users/gt3409/plotting_maps

# %%
# %%time
from acs_plotting_maps import *
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from matplotlib import colors, cm
# Out:
# CPU times: user 5.4 s, sys: 1.3 s, total: 6.7 s
# Wall time: 8.29 s

# %%
regions = regions_dict['ncra_regions']
watermark=""
issued_date=""

# %%
# %%time 

# Severe or extreme heatwave days map 
var = "HW_sev_ext"

ds_gwl12 = xr.open_dataset(f"/g/data/ia39/ncra/heat/data/{var}/bias-corrected/ensemble/GWL-average/{var}_AGCD-05i_MME50_ssp370_v1-r1-ACS-QME-AGCD-1960-2022_GWL12.nc")
ds_gwl15 = xr.open_dataset(f"/g/data/ia39/ncra/heat/data/{var}/bias-corrected/ensemble/GWL-change/{var}_AGCD-05i_MME50_ssp370_v1-r1-ACS-QME-AGCD-1960-2022_GWL15-GWL12-change.nc")
ds_gwl20 = xr.open_dataset(f"/g/data/ia39/ncra/heat/data/{var}/bias-corrected/ensemble/GWL-change/{var}_AGCD-05i_MME50_ssp370_v1-r1-ACS-QME-AGCD-1960-2022_GWL20-GWL12-change.nc")
ds_gwl30 = xr.open_dataset(f"/g/data/ia39/ncra/heat/data/{var}/bias-corrected/ensemble/GWL-change/{var}_AGCD-05i_MME50_ssp370_v1-r1-ACS-QME-AGCD-1960-2022_GWL30-GWL12-change.nc")


ticks_current=np.arange(0,12, 2)
cmap_current=cmap_dict["EHF_days"]
label_current="heatwave days\n[days per year]"

ticks_future=np.arange(-2,18,2)
cmap_future=cmap_dict["ipcc_temp_div"]
label_future=f"change in\n{label_current}"

plot_acs_hazard(data=ds_gwl12[var],
                title="",
                cmap=cmap_current,
                cbar_extend= "max",
                cbar_label=label_current,
                ticks=ticks_current,
                regions = regions,
                watermark=watermark,
                issued_date=issued_date,
                outfile=f"figures/story_map_plots_{var}_gwl12",
                )

for i, ds_gwl in enumerate([ds_gwl15,ds_gwl20, ds_gwl30]):
    plot_acs_hazard(data=ds_gwl[var],
                    title="",
                    regions = regions,
                    cmap = cmap_future,
                    ticks = ticks_future,
                    cbar_label = label_future,
                    watermark=watermark,
                    issued_date=issued_date,
                    vcentre=0,
                    outfile=f"figures/story_map_plots_{var}_gwl{[15,20,30][i]}"
                    )
# Out:
# CPU times: user 9min 22s, sys: 3.48 s, total: 9min 26s
# Wall time: 9min 30s

# %%
# %%time
# Time spent in drought maps 

var="SPI3"

ds_gwl12 = xr.open_dataset(f"/g/data/ia39/ncra/drought_aridity/spi/downscaled_BC_5km/SPI3_pct_time_below_-1_GWL_1.2_ACS-QME-AGCD-1960-2022_percentiles_10-50-90.nc").sel(quantile = 0.5)
ds_gwl15 = xr.open_dataset(f"/g/data/ia39/ncra/drought_aridity/spi/downscaled_BC_5km/SPI3_pct_time_below_-1_MME_change_GWL1.5_to_GWL1.2_ACS-QME-AGCD-1960-2022_percentiles_10-50-90.nc").sel(quantile = 0.5)
ds_gwl20 = xr.open_dataset(f"/g/data/ia39/ncra/drought_aridity/spi/downscaled_BC_5km/SPI3_pct_time_below_-1_MME_change_GWL2.0_to_GWL1.2_ACS-QME-AGCD-1960-2022_percentiles_10-50-90.nc").sel(quantile = 0.5)
ds_gwl30 = xr.open_dataset(f"/g/data/ia39/ncra/drought_aridity/spi/downscaled_BC_5km/SPI3_pct_time_below_-1_MME_change_GWL3.0_to_GWL1.2_ACS-QME-AGCD-1960-2022_percentiles_10-50-90.nc").sel(quantile = 0.5)

ticks_current= np.arange(0,35, 5)
cmap_current=cm.YlOrBr
label_current="time in drought\n[%]"

ticks_future=np.arange(-75, 76, 25)
cmap_future=cmap_dict["aridity_anom_r"]
label_future=f"change in\n{label_current}"

plot_acs_hazard(data=ds_gwl12[var],
                title="",
                cmap=cmap_current,
                cbar_extend= "max",
                cbar_label=label_current,
                ticks=ticks_current,
                regions = regions,
                agcd_mask=True,
                watermark=watermark,
                issued_date=issued_date,
                outfile=f"figures/story_map_plots_{var}_gwl12",
                )

for i, ds_gwl in enumerate([ds_gwl15,ds_gwl20, ds_gwl30]):
    plot_acs_hazard(data=ds_gwl[var],
                    title="",
                    regions = regions,
                    agcd_mask=True,
                    cmap = cmap_future,
                    ticks = ticks_future,
                    cbar_label = label_future,
                    watermark=watermark,
                    issued_date=issued_date,
                    outfile=f"figures/story_map_plots_{var}_gwl{[15,20,30][i]}"
                    )
# Out:
# CPU times: user 7min 22s, sys: 930 ms, total: 7min 23s
# Wall time: 7min 23s

# %%
# %%time 

# Changes in days of severe fire danger maps

var = "days50"

ffdi_ge50_mmm = xr.open_dataset(f"/g/data/ia39/ncra/fire/change_threshold_50.nc")

ds_gwl12 = xr.open_dataset("/g/data/ia39/ncra/fire/GWL1p2_threshold_50.nc").drop_vars(["period"])
ds_gwl15 = ffdi_ge50_mmm.sel(period=1).drop_vars(["period"])
ds_gwl20 = ffdi_ge50_mmm.sel(period=2).drop_vars(["period"])
ds_gwl30 = ffdi_ge50_mmm.sel(period=3).drop_vars(["period"])


ticks_current= [0, 1, 5, 10, 15, 30, 60, 90, 150,]
cmap_current=cmap_dict["EHF_days"]
label_current="FFDI > 50\n[days per year]"

ticks_future=[0, 1, 5, 10, 15, 30, 60, 90,]
cmap_future=cmap_dict["ipcc_temp_seq"]
label_future=f"change in\n{label_current}"

plot_acs_hazard(data=ds_gwl12[var],
                title="",
                cmap=cmap_current,
                cbar_extend= "max",
                cbar_label=label_current,
                ticks=ticks_current,
                regions = regions,
                watermark=watermark,
                issued_date=issued_date,
                outfile=f"figures/story_map_plots_FFDI{var}_gwl12",
                )

for i, ds_gwl in enumerate([ds_gwl15,ds_gwl20, ds_gwl30]):
    plot_acs_hazard(data=ds_gwl[var],
                    title="",
                    regions = regions,
                    cmap = cmap_future,
                    cbar_extend= "max",
                    ticks = ticks_future,
                    cbar_label = label_future,
                    watermark=watermark,
                    issued_date=issued_date,
                    outfile=f"figures/story_map_plots_FFDI{var}_gwl{[15,20,30][i]}"
                    )
# Out:
# CPU times: user 7min 20s, sys: 976 ms, total: 7min 21s
# Wall time: 7min 21s

# %%
# %%time

# Marine heatwave duration maps
var="duration"

ds_gwl12 =  xr.open_dataset(f"/g/data/ia39/ncra/ocean/GW1p2_mhw.nc").rename({"xt_ocean":"lon", "yt_ocean":"lat"})
ds_gwl15 =  xr.open_dataset(f"/g/data/ia39/ncra/ocean/GW1p5_mhw.nc").rename({"xt_ocean":"lon", "yt_ocean":"lat"})
ds_gwl20 =  xr.open_dataset(f"/g/data/ia39/ncra/ocean/GW2p0_mhw.nc").rename({"xt_ocean":"lon", "yt_ocean":"lat"})
ds_gwl30 =  xr.open_dataset(f"/g/data/ia39/ncra/ocean/GW3p0_mhw.nc").rename({"xt_ocean":"lon", "yt_ocean":"lat"})

ticks_current= [0, 15, 30, 60, 90, 180, 360]
cmap_current=cmap_dict['ipcc_temp_seq']
label_current="heatwave days\n[days per year]"

ticks_future=[-15, 0, 15, 30, 90, 180, 360]
cmap_future=cmap_dict["ipcc_temp_div"]
label_future=f"change in\n{label_current}"

plot_acs_hazard(data=ds_gwl12[var],
                title="",
                cmap=cmap_current,
                cbar_extend= "max",
                cbar_label=label_current,
                ticks=ticks_current,
                regions = regions,
                mask_not_australia=False,
                mask_australia=True,
                watermark=watermark,
                issued_date=issued_date,
                outfile=f"figures/story_map_plots_MHW{var}_gwl12",
                )

for i, ds_gwl in enumerate([ds_gwl15,ds_gwl20, ds_gwl30]):
    plot_acs_hazard(data=ds_gwl[var],
                    title="",
                    regions = regions,
                    mask_not_australia=False,
                    mask_australia=True,
                    cmap = cmap_future,
                    ticks = ticks_future,
                    cbar_label = label_future,
                    watermark=watermark,
                    issued_date=issued_date,
                    vcentre=0,
                    outfile=f"figures/story_map_plots_MHW{var}_gwl{[15,20,30][i]}"
                    )
# Out:
# CPU times: user 9min 47s, sys: 5.59 s, total: 9min 53s
# Wall time: 9min 53s

# %%
# %%time
# Maximum Daily runoff maps

var="runoff"


ds_gwl12 = xr.open_dataset(f"/g/data/ia39/ncra/flood/Runoff_Max1D/runoff_max1day_ens_perc/max1day_runoff_ens_perc_1.2.nc")\
.rename({"longitude":"lon", "latitude":"lat", "runoff_1.2":var}).sel(quantile = 0.5)
ds_gwl15 = xr.open_dataset(f"/g/data/ia39/ncra/flood/Runoff_Max1D/runoff_max1day_ens_change_perc/max1day_runoff_ens_change_perc_1.5.nc")\
.rename({"longitude":"lon", "latitude":"lat", "runoff_1.5":var}).sel(quantile = 0.5)
ds_gwl20 = xr.open_dataset(f"/g/data/ia39/ncra/flood/Runoff_Max1D/runoff_max1day_ens_change_perc/max1day_runoff_ens_change_perc_2.nc")\
.rename({"longitude":"lon", "latitude":"lat", "runoff_2":var}).sel(quantile = 0.5)
ds_gwl30 = xr.open_dataset(f"/g/data/ia39/ncra/flood/Runoff_Max1D/runoff_max1day_ens_change_perc/max1day_runoff_ens_change_perc_3.nc")\
.rename({"longitude":"lon", "latitude":"lat", "runoff_3":var}).sel(quantile = 0.5)


ticks_current=[0,2,5,10,20,50,100,150]
cmap_current=cmap_dict["pr"]
label_current="runoff\n[mm/day]"

ticks_future=[-50, -25, -10, 0, 10, 25, 50]
cmap_future=cmap_dict["pr_anom"]
label_future="change in\nrunoff\n[%]"

plot_acs_hazard(data=ds_gwl12[var],
                title="",
                cmap=cmap_current,
                cbar_extend= "max",
                cbar_label=label_current,
                ticks=ticks_current,
                regions = regions,
                agcd_mask=True,
                watermark=watermark,
                issued_date=issued_date,
                outfile=f"figures/story_map_plots_{var}_gwl12",
                )

for i, ds_gwl in enumerate([ds_gwl15,ds_gwl20, ds_gwl30]):
    plot_acs_hazard(data=ds_gwl[var],
                    title="",
                    regions = regions,
                    agcd_mask=True,
                    cmap = cmap_future,
                    ticks = ticks_future,
                    cbar_label = label_future,
                    watermark=watermark,
                    issued_date=issued_date,
                    outfile=f"figures/story_map_plots_{var}_gwl{[15,20,30][i]}"
                    )
# Out:
# CPU times: user 7min 33s, sys: 808 ms, total: 7min 34s
# Wall time: 7min 35s

# %%
# %%time
# Coastal Flood extent maps

var = "ext_50"

df = pd.read_csv("/g/data/ia39/ncra/coastal/flood_extents/inundation_stats/results_2020_change.csv")

df_gwl12=df.where(df["SLR"]==0.2).dropna()[["lat", "lon", var]].sort_values(var)
df_gwl15=df.where(df["SLR"]==0.38).dropna()[["lat", "lon", var]].sort_values(var)
df_gwl20=df.where(df["SLR"]==0.60).dropna()[["lat", "lon", var]].sort_values(var)
df_gwl30=df.where(df["SLR"]==1.00).dropna()[["lat", "lon", var]].sort_values(var)

ticks_future=np.arange(0,71,10)
cmap_future=cmap_dict["xts_freq"]
label_future="change in\nflood extent\n[km\N{SUPERSCRIPT TWO}]"


for i, station_df in enumerate([df_gwl12, df_gwl15, df_gwl20, df_gwl30]):
    plot_acs_hazard(station_df=station_df,
                    title="",
                    regions = regions,
                    facecolor="lightgrey",
                    cmap = cmap_future,
                    cbar_extend="max",
                    ticks = ticks_future,
                    cbar_label = label_future,
                    watermark=watermark,
                    issued_date=issued_date,
                    outfile=f"figures/story_map_plots_coastal-flood-{var}_gwl{[12,15,20,30][i]}"
                    )
# Out:
# CPU times: user 7min 24s, sys: 870 ms, total: 7min 25s
# Wall time: 7min 25s

# %%
# %%time
# Changes in extreme coastal erosion maps
#The MTWL MF is primarily a metric to evaluate the increase in coastal erosion for ocean coasts.

var = "MTWL_MFSLR_50"

df_gwl12 = pd.read_csv("/g/data/ia39/ncra/coastal/MF/difference_files/MFSLR_ACSSH_MMALL_SLR14cm.csv")\
.rename(columns={"latitude":"lat", "longitude":"lon"})[["lat", "lon", var]].sort_values(var)
df_gwl15 = pd.read_csv("/g/data/ia39/ncra/coastal/MF/difference_files/MFSLR_ACSSH_MMALL_SLR32cm.csv")\
.rename(columns={"latitude":"lat", "longitude":"lon"})[["lat", "lon", var]].sort_values(var)
df_gwl20 = pd.read_csv("/g/data/ia39/ncra/coastal/MF/difference_files/MFSLR_ACSSH_MMALL_SLR54cm.csv")\
.rename(columns={"latitude":"lat", "longitude":"lon"})[["lat", "lon", var]].sort_values(var)
df_gwl30 = pd.read_csv("/g/data/ia39/ncra/coastal/MF/difference_files/MFSLR_ACSSH_MMALL_SLR94cm.csv")\
.rename(columns={"latitude":"lat", "longitude":"lon"})[["lat", "lon", var]].sort_values(var)

ticks_future=[0,1,5,10,30,50,100,200, 400]
cmap_future=cmap_dict["EHF_duration"]
label_future="change in\nstorm tide plus wave effects\n[multiplication factor]"

for i, station_df in enumerate([df_gwl12, df_gwl15, df_gwl20, df_gwl30]):
    plot_acs_hazard(station_df=station_df,
                    title="",
                    regions = regions,
                    facecolor="lightgrey",
                    cmap = cmap_future,
                    cbar_extend="max",
                    ticks = ticks_future,
                    cbar_label = label_future,
                    watermark=watermark,
                    issued_date=issued_date,
                    outfile=f"figures/story_map_plots_{var}_gwl{[12,15,20,30][i]}"
                    )
# Out:
# CPU times: user 7min 26s, sys: 771 ms, total: 7min 27s
# Wall time: 7min 27s

# %%
# %%time
# Changes in extreme coastal flooding hazard 

var = "SWL_MFSLR_50"

df_gwl12 = pd.read_csv("/g/data/ia39/ncra/coastal/MF/difference_files/MFSLR_ACSSH_MMALL_SLR14cm.csv").rename(columns={"latitude":"lat", "longitude":"lon"})[["lat", "lon", var]].sort_values(var)
df_gwl15 = pd.read_csv("/g/data/ia39/ncra/coastal/MF/difference_files/MFSLR_ACSSH_MMALL_SLR32cm.csv").rename(columns={"latitude":"lat", "longitude":"lon"})[["lat", "lon", var]].sort_values(var)
df_gwl20 = pd.read_csv("/g/data/ia39/ncra/coastal/MF/difference_files/MFSLR_ACSSH_MMALL_SLR54cm.csv").rename(columns={"latitude":"lat", "longitude":"lon"})[["lat", "lon", var]].sort_values(var)
df_gwl30 = pd.read_csv("/g/data/ia39/ncra/coastal/MF/difference_files/MFSLR_ACSSH_MMALL_SLR94cm.csv").rename(columns={"latitude":"lat", "longitude":"lon"})[["lat", "lon", var]].sort_values(var)

ticks_future=[0,1,5,10,30,50,100,200, 400]
cmap_future=cmap_dict["xts_freq"]
label_future="change in\nstorm tide\n[multiplication factor]"

for i, station_df in enumerate([df_gwl12, df_gwl15, df_gwl20, df_gwl30]):
    plot_acs_hazard(station_df=station_df,
                    title="",
                    regions = regions,
                    facecolor="lightgrey",
                    cmap = cmap_future,
                    cbar_extend="max",
                    ticks = ticks_future,
                    cbar_label = label_future,
                    watermark=watermark,
                    issued_date=issued_date,
                    outfile=f"figures/{var}_gwl{[12,15,20,30][i]}"
                    )
# Out:
# CPU times: user 7min 24s, sys: 688 ms, total: 7min 25s
# Wall time: 7min 25s

# %%
# %%time
# var = "low_freq"

# ds_gwl12 = xr.open_dataset(f"/g/data/ia39/ncra/extratropical_storms/5km/GWLs/lows_AGCD-05i_MM50_ssp370_v1-r1_GWL12.nc")\
# .where(ds_gwl12["lat"]<=-28)
# ds_gwl15 = xr.open_dataset(f"/g/data/ia39/ncra/extratropical_storms/5km/GWLs/lows_AGCD-05i_MM50_ssp370_v1-r1_GWL15_change.nc")\
# .where(ds_gwl15["lat"]<=-28)
# ds_gwl20 = xr.open_dataset(f"/g/data/ia39/ncra/extratropical_storms/5km/GWLs/lows_AGCD-05i_MM50_ssp370_v1-r1_GWL20_change.nc")\
# .where(ds_gwl20["lat"]<=-28)
# ds_gwl30 = xr.open_dataset(f"/g/data/ia39/ncra/extratropical_storms/5km/GWLs/lows_AGCD-05i_MM50_ssp370_v1-r1_GWL30_change.nc")\
# .where(ds_gwl30["lat"]<=-28)

# ticks_current=np.arange(0,3.1, 0.5)
# cmap_current=cmap_dict["xts_freq"]
# label_current="time influenced by a low\n[%]"

# ticks_future=ticks = np.arange(-40,41,10)
# cmap_future=cmap_dict["xts_freq_anom"]
# label_future="change in\nlow frequency\n[%]"

# plot_acs_hazard(data=ds_gwl12[var]*100,
#                 title="",
#                 cmap=cmap_current,
#                 cmap_bad="w",
#                 cbar_extend= "max",
#                 cbar_label=label_current,
#                 ticks=ticks_current,
#                 regions = regions,
#                 watermark=watermark,
#                 issued_date=issued_date,
#                 outfile=f"figures/story_map_plots_{var}_gwl12",
#                 )

# for i, ds_gwl in enumerate([ds_gwl15,ds_gwl20, ds_gwl30]):
#     plot_acs_hazard(data=ds_gwl[var],
#                     title="",
#                     regions = regions,
#                     cmap = cmap_future,
#                     cmap_bad="w",
#                     ticks = ticks_future,
#                     cbar_label = label_future,
#                     watermark=watermark,
#                     issued_date=issued_date,
#                     vcentre=0,
#                     outfile=f"figures/story_map_plots_{var}_gwl{[15,20,30][i]}"
#                     )

# %%
# %%time 

# Severe or extreme heatwave days map 
var = "HW_sev_ext"

ds_gwl12 = xr.open_dataset(f"/g/data/ia39/ncra/heat/data/{var}/bias-corrected/ensemble/GWL-average/{var}_AGCD-05i_MME50_ssp370_v1-r1-ACS-QME-AGCD-1960-2022_GWL12.nc")
ds_gwl15 = xr.open_dataset(f"/g/data/ia39/ncra/heat/data/{var}/bias-corrected/ensemble/GWL-change/{var}_AGCD-05i_MME50_ssp370_v1-r1-ACS-QME-AGCD-1960-2022_GWL15-GWL12-change.nc")
ds_gwl20 = xr.open_dataset(f"/g/data/ia39/ncra/heat/data/{var}/bias-corrected/ensemble/GWL-change/{var}_AGCD-05i_MME50_ssp370_v1-r1-ACS-QME-AGCD-1960-2022_GWL20-GWL12-change.nc")
ds_gwl30 = xr.open_dataset(f"/g/data/ia39/ncra/heat/data/{var}/bias-corrected/ensemble/GWL-change/{var}_AGCD-05i_MME50_ssp370_v1-r1-ACS-QME-AGCD-1960-2022_GWL30-GWL12-change.nc")


ticks_current=np.arange(0,12, 2)
cmap_current=cmap_dict["acs_temperature_seq1"]
label_current="heatwave days\n[days per year]"

ticks_future=np.arange(-2,18,2)
cmap_future=cmap_dict["acs_temperature_div1"]
label_future=f"change in\n{label_current}"

plot_acs_hazard(data=ds_gwl12[var],
                title="",
                cmap=cmap_current,
                cbar_extend= "max",
                cbar_label=label_current,
                ticks=ticks_current,
                regions = regions,
                watermark=watermark,
                issued_date=issued_date,
                outfile=f"figures/story_map_plots_{var}_gwl12",
                )

for i, ds_gwl in enumerate([ds_gwl15,ds_gwl20, ds_gwl30]):
    plot_acs_hazard(data=ds_gwl[var],
                    title="",
                    regions = regions,
                    cmap = cmap_future,
                    ticks = ticks_future,
                    cbar_label = label_future,
                    watermark=watermark,
                    issued_date=issued_date,
                    vcentre=0,
                    outfile=f"figures/story_map_plots_{var}_gwl{[15,20,30][i]}_new-colors"
                    )
# Out:
# CPU times: user 7min 26s, sys: 804 ms, total: 7min 27s
# Wall time: 7min 27s

# %%
# %%time

# Marine heatwave duration maps
var="duration"

ds_gwl12 =  xr.open_dataset(f"/g/data/ia39/ncra/ocean/GW1p2_mhw.nc").rename({"xt_ocean":"lon", "yt_ocean":"lat"})
ds_gwl15 =  xr.open_dataset(f"/g/data/ia39/ncra/ocean/GW1p5_mhw.nc").rename({"xt_ocean":"lon", "yt_ocean":"lat"})
ds_gwl20 =  xr.open_dataset(f"/g/data/ia39/ncra/ocean/GW2p0_mhw.nc").rename({"xt_ocean":"lon", "yt_ocean":"lat"})
ds_gwl30 =  xr.open_dataset(f"/g/data/ia39/ncra/ocean/GW3p0_mhw.nc").rename({"xt_ocean":"lon", "yt_ocean":"lat"})

ticks_current= [0, 15, 30, 60, 90, 180, 360]
cmap_current=cmap_dict['acs_temperature_seq1']
label_current="heatwave days\n[days per year]"

ticks_future=[-15, 0, 15, 30, 90, 180, 360]
cmap_future=cmap_dict["acs_temperature_div1"]
label_future=f"change in\n{label_current}"

plot_acs_hazard(data=ds_gwl12[var],
                title="",
                cmap=cmap_current,
                cbar_extend= "max",
                cbar_label=label_current,
                ticks=ticks_current,
                regions = regions,
                mask_not_australia=False,
                mask_australia=True,
                watermark=watermark,
                issued_date=issued_date,
                outfile=f"figures/story_map_plots_MHW{var}_gwl12_new-colors",
                )

for i, ds_gwl in enumerate([ds_gwl15,ds_gwl20, ds_gwl30]):
    plot_acs_hazard(data=ds_gwl[var],
                    title="",
                    regions = regions,
                    mask_not_australia=False,
                    mask_australia=True,
                    cmap = cmap_future,
                    ticks = ticks_future,
                    cbar_label = label_future,
                    watermark=watermark,
                    issued_date=issued_date,
                    vcentre=0,
                    outfile=f"figures/story_map_plots_MHW{var}_gwl{[15,20,30][i]}_new-colors"
                    )
# Out:
# CPU times: user 8min 1s, sys: 5.16 s, total: 8min 6s
# Wall time: 8min 6s

# %%
# %%time
# Maximum Daily runoff maps

var="runoff"


ds_gwl12 = xr.open_dataset(f"/g/data/ia39/ncra/flood/Runoff_Max1D/runoff_max1day_ens_perc/max1day_runoff_ens_perc_1.2.nc")\
.rename({"longitude":"lon", "latitude":"lat", "runoff_1.2":var}).sel(quantile = 0.5)
ds_gwl15 = xr.open_dataset(f"/g/data/ia39/ncra/flood/Runoff_Max1D/runoff_max1day_ens_change_perc/max1day_runoff_ens_change_perc_1.5.nc")\
.rename({"longitude":"lon", "latitude":"lat", "runoff_1.5":var}).sel(quantile = 0.5)
ds_gwl20 = xr.open_dataset(f"/g/data/ia39/ncra/flood/Runoff_Max1D/runoff_max1day_ens_change_perc/max1day_runoff_ens_change_perc_2.nc")\
.rename({"longitude":"lon", "latitude":"lat", "runoff_2":var}).sel(quantile = 0.5)
ds_gwl30 = xr.open_dataset(f"/g/data/ia39/ncra/flood/Runoff_Max1D/runoff_max1day_ens_change_perc/max1day_runoff_ens_change_perc_3.nc")\
.rename({"longitude":"lon", "latitude":"lat", "runoff_3":var}).sel(quantile = 0.5)


ticks_current=[0,2,5,10,20,50,100,150]
cmap_current=cmap_dict["acs_precipitation_seq2"]
label_current="runoff\n[mm/day]"

ticks_future=[-50, -25, -10, 0, 10, 25, 50]
cmap_future=cmap_dict["acs_precipitation_div2"]
label_future="change in\nrunoff\n[%]"

plot_acs_hazard(data=ds_gwl12[var],
                title="",
                cmap=cmap_current,
                cbar_extend= "max",
                cbar_label=label_current,
                ticks=ticks_current,
                regions = regions,
                agcd_mask=True,
                watermark=watermark,
                issued_date=issued_date,
                outfile=f"figures/story_map_plots_{var}_gwl12_new-colors",
                )

for i, ds_gwl in enumerate([ds_gwl15,ds_gwl20, ds_gwl30]):
    plot_acs_hazard(data=ds_gwl[var],
                    title="",
                    regions = regions,
                    agcd_mask=True,
                    cmap = cmap_future,
                    ticks = ticks_future,
                    cbar_label = label_future,
                    watermark=watermark,
                    issued_date=issued_date,
                    outfile=f"figures/story_map_plots_{var}_gwl{[15,20,30][i]}_new-colors"
                    )
# Out:
# CPU times: user 7min 21s, sys: 638 ms, total: 7min 21s
# Wall time: 7min 21s
