# %%
# This notebook is a trial to mask raw Cordex data and extract timeseries

# %%
# navigate to correct location to access modules

# %%
cd /g/data/mn51/users/gt3409/plotting_maps/
# Out:
# /g/data/mn51/users/gt3409/plotting_maps

# %%
from acs_area_statistics import acs_regional_stats
import xarray as xr
import geopandas as gpd
import regionmask
from glob import glob
import numpy as np

import pandas as pd

# %%
# import dask
# from dask.distributed import Client, LocalCluster
# dask.config.set({'distributed.worker.daemon': False})
# # cluster = LocalCluster(n_workers=14, processes=True, threads_per_worker=1)
# client = Client()  # start distributed scheduler locally.
# client
# # client.cluster.adapt(minimum=0, maximum=24)

# %%
shapefile_list = ["aus_local_gov",
                  "aus_states_territories",
                  "australia", 
                  "broadacre_regions", 
                  "ncra_regions", 
                  "NCRA_regions_coastal_waters_GDA94", 
                  "nrm_regions", ]

name_dict = {"aus_local_gov":"LGA_NAME22", 
             "aus_states_territories":"STE_NAME21",
             "australia": "AUS_NAME21",
             "broadacre_regions": "name",
             "ncra_regions": "regionname", 
             "NCRA_regions_coastal_waters_GDA94": "regionname",
             "nrm_regions":"SubClusNm",
            }


abbr_dict = {"aus_local_gov":"LGA_CODE22", 
             "aus_states_territories":"ABBREV",
             "australia": "AUS_CODE21",
             "broadacre_regions": "aagis",
             "ncra_regions": "short_name", 
             "NCRA_regions_coastal_waters_GDA94": "NCRA",
             "nrm_regions": "SubClusAb",
            }

def get_regions(shapefiles):
    """
    This function takes a list of names of shape files from ia39 and
    returns a combined regionmask.
    
    Parameters
    -----------
    name: str
        one of "aus_local_gov", "aus_states_territories", "australia", 
        "nrm_regions", "ncra_regions","broadacre_regions",
        "NCRA_regions_coastal_waters_GDA94"

    Returns
    -------
    geopandas dataframe
    
    """
    gdfs = {}
    PATH = "/g/data/ia39/aus-ref-clim-data-nci/shapefiles/data"
    
    for i, shapefile in enumerate(shapefiles):
        gdfs[i] = gpd.read_file(glob(f"{PATH}/{shapefile}/*.shp")[0]).rename(columns = {name_dict[shapefile]:"NAME", abbr_dict[shapefile]:"abbrevs"}).to_crs(crs = "GDA2020")
    gdf = pd.concat(gdfs)
    gdf.index = np.arange(0, len(gdf))
    return regionmask.from_geopandas(gdf, names="NAME", abbrevs="abbrevs", name= "-".join(shapefiles), overlap=True)

# %%
PATH = "/g/data/ia39/aus-ref-clim-data-nci/shapefiles/data"
name = "aus_local_gov"
gdf = gpd.read_file(f"{PATH}/{name}/{name}.shp")
gdf
# Out:
#     LGA_CODE22                   LGA_NAME22 STE_CODE21  \
# 0        10050                       Albury          1
# 1        10180                     Armidale          1
# 2        10250                      Ballina          1
# 3        10300                    Balranald          1
# 4        10470                     Bathurst          1
# ..         ...                          ...        ...
# 542      74660                  West Arnhem          7
# 543      74680                    West Daly          7
# 544      79399            Unincorporated NT          7
# 545      89399           Unincorporated ACT          8
# 546      99399  Unincorp. Other Territories          9
#
#                        STE_NAME21    AREASQKM  \
# 0                 New South Wales    305.6386
# 1                 New South Wales   7809.4406
# 2                 New South Wales    484.9692
# 3                 New South Wales  21690.7493
# 4                 New South Wales   3817.8645
# ..                            ...         ...
# 542            Northern Territory  49675.0342
# 543            Northern Territory  14069.6980
# 544            Northern Territory  19777.3595
# 545  Australian Capital Territory   2358.1330
# 546             Other Territories    105.8806
#
#                                             LOCI_URI21  SHAPE_Leng  \
# 0    https://linked.data.gov.au/dataset/asgsed3/LGA...    1.321768
# 1    https://linked.data.gov.au/dataset/asgsed3/LGA...    6.034583
# 2    https://linked.data.gov.au/dataset/asgsed3/LGA...    1.511121
# 3    https://linked.data.gov.au/dataset/asgsed3/LGA...   11.489912
# 4    https://linked.data.gov.au/dataset/asgsed3/LGA...    5.395114
# ..                                                 ...         ...
# 542  https://linked.data.gov.au/dataset/asgsed3/LGA...   23.235319
# 543  https://linked.data.gov.au/dataset/asgsed3/LGA...    7.556529
# 544  https://linked.data.gov.au/dataset/asgsed3/LGA...   19.180110
# 545  https://linked.data.gov.au/dataset/asgsed3/LGA...    3.032133
# 546  https://linked.data.gov.au/dataset/asgsed3/LGA...    1.301008
#
#      SHAPE_Area                                           geometry
# 0      0.030560  POLYGON ((146.86566 -36.07292, 146.86512 -36.0...
# 1      0.732825  POLYGON ((152.38816 -30.52639, 152.38812 -30.5...
# 2      0.044843  MULTIPOLYGON (((153.57106 -28.87381, 153.57106...
# 3      2.115528  POLYGON ((143.00433 -33.78164, 143.01538 -33.7...
# 4      0.370149  POLYGON ((149.84877 -33.52784, 149.84864 -33.5...
# ..          ...                                                ...
# 542    4.130572  MULTIPOLYGON (((132.99069 -11.07872, 132.99049...
# 543    1.178262  MULTIPOLYGON (((129.69308 -14.80637, 129.69233...
# 544    1.648842  MULTIPOLYGON (((130.74789 -12.42749, 130.74985...
# 545    0.234227  POLYGON ((149.06239 -35.15910, 149.09134 -35.1...
# 546    0.010231  MULTIPOLYGON (((167.94747 -29.12757, 167.94748...
#
# [547 rows x 9 columns]

# %%
# %%time

# for many regions

PATH = "/g/data/ia39/aus-ref-clim-data-nci/shapefiles/data"
name = ["aus_local_gov",
                  "aus_states_territories",
                  "australia", 
                  "broadacre_regions", 
                  "ncra_regions", 
                  "NCRA_regions_coastal_waters_GDA94", 
                  "nrm_regions", ][0]
regions = get_regions([name])


variable_id = "tasmaxAdjust"
institution_id = "BOM"
parent_model = "ACCESS-CM2"
downscaling_model = "BARPA-R"
member_id = "r4i1p1f1"

common_dir = f"/g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-output/AGCD-05i"


start_year= 2000
end_year=2030

experiment_id = "historical"
filelist_hist = [f"{common_dir}/{institution_id}/{parent_model}/{experiment_id}/{member_id}/{downscaling_model}/v1-r1-ACS-QME-AGCD-1960-2022/day/{variable_id}/{variable_id}_AGCD-05i_{parent_model}_{experiment_id}_{member_id}_{institution_id}_{downscaling_model}_v1-r1-ACS-QME-AGCD-1960-2022_day_{year}0101-{year}1231.nc" 
                 for year in np.arange(start_year,2015,1)]
experiment_id = "ssp370"
filelist_ssp370 = [f"{common_dir}/{institution_id}/{parent_model}/{experiment_id}/{member_id}/{downscaling_model}/v1-r1-ACS-QME-AGCD-1960-2022/day/{variable_id}/{variable_id}_AGCD-05i_{parent_model}_{experiment_id}_{member_id}_{institution_id}_{downscaling_model}_v1-r1-ACS-QME-AGCD-1960-2022_day_{year}0101-{year}1231.nc" 
                   for year in np.arange(2015,end_year,1)]

filelist = filelist_hist + filelist_ssp370


ds = xr.open_dataset(filelist[0])

# mask = regions.mask_3D_frac_approx(ds)
mask = xr.open_dataset("/scratch/eg3/gt3409/mask_3D_frac_approx_aus_local_gov.nc")["mask"]

lat_weights = np.cos(np.deg2rad(ds["lat"]))

def _preprocess(ds, mask):
    return ds.chunk(chunks={"time":10, "lat": -1, "lon":-1}).weighted(mask * lat_weights)\
             .mean(["lat", "lon"])
    
ds_mf = xr.open_mfdataset(filelist, preprocess=lambda ds: _preprocess(ds[variable_id], mask),
                          autoclose=True, combine="nested", concat_dim="time")
ds_mf = ds_mf.compute()
ds_mf
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/dask/array/routines.py:332: PerformanceWarning: Increasing number of chunks by factor of 36
#   intermediate = blockwise(
# CPU times: user 1h 22min 54s, sys: 23min 21s, total: 1h 46min 15s
# Wall time: 9min 16s
# <xarray.DataArray 'tasmaxAdjust' (time: 10958, region: 545)> Size: 48MB
# array([[32.55035848, 27.81376555, 29.19174555, ..., 35.29152664,
#         28.80829416, 25.86229443],
#        [31.37419907, 30.66193227, 31.6402308 , ..., 35.53099192,
#         32.53835499, 29.41152601],
#        [22.87959824, 31.23126888, 35.50825602, ..., 35.29557924,
#         19.49431945, 24.78610105],
#        ...,
#        [25.89848448, 20.55905894, 25.84247749, ..., 34.8720158 ,
#         17.8918767 , 20.35408157],
#        [28.1558822 , 23.0959236 , 27.11825944, ..., 35.89306755,
#         22.82878364, 22.61419251],
#        [33.42785959, 24.6200125 , 28.35939553, ..., 36.53081756,
#         27.70703742, 25.78018877]])
# Coordinates:
#   * time     (time) datetime64[ns] 88kB 2000-01-01T12:00:00 ... 2029-12-31T12...
#   * region   (region) int64 4kB 0 1 2 3 4 5 6 7 ... 540 541 542 543 544 545 546
#     abbrevs  (region) <U5 11kB '10050' '10180' '10250' ... '89399' '99399'
#     names    (region) <U37 81kB 'Albury' ... 'Unincorp. Other Territories'

# %%
# %%time 
#this is super memory intensive, so will save to avoid recalculating
mask = regions.mask_3D_frac_approx(ds)
mask.to_netcdf("/scratch/eg3/gt3409/mask_3D_frac_approx_aus_local_gov.nc")
# Out:
# CPU times: user 2min 59s, sys: 24.1 s, total: 3min 23s
# Wall time: 3min 23s

# %%
mask.to_netcdf("/scratch/eg3/gt3409/mask_3D_aus_local_gov.nc")

# %%
filelist
# Out:
# ['/g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-output/AGCD-05i/BOM/ACCESS-CM2/historical/r4i1p1f1/BARPA-R/v1-r1-ACS-QME-AGCD-1960-2022/day/tasmaxAdjust/tasmaxAdjust_AGCD-05i_ACCESS-CM2_historical_r4i1p1f1_BOM_BARPA-R_v1-r1-ACS-QME-AGCD-1960-2022_day_20140101-20141231.nc',
#  '/g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-output/AGCD-05i/BOM/ACCESS-CM2/ssp370/r4i1p1f1/BARPA-R/v1-r1-ACS-QME-AGCD-1960-2022/day/tasmaxAdjust/tasmaxAdjust_AGCD-05i_ACCESS-CM2_ssp370_r4i1p1f1_BOM_BARPA-R_v1-r1-ACS-QME-AGCD-1960-2022_day_20150101-20151231.nc']

# %%
# %%time
results = []
for file in filelist:
    results.append(_preprocess(ds, mask))
dask.compute(results)

# %%
# %%time
ds_mf = ds_mf.compute()
ds_mf

# %%
# %%time

# for many regions

PATH = "/g/data/ia39/aus-ref-clim-data-nci/shapefiles/data"
name = "aus_states_territories"
regions = get_regions([name])

variable_id = "tasmaxAdjust"

institution_id = "BOM"
parent_model = "ACCESS-CM2"
downscaling_model = "BARPA-R"
member_id = "r4i1p1f1"

common_dir = f"/g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-output/AGCD-05i"

experiment_id = "historical"
filelist_hist = [f"{common_dir}/{institution_id}/{parent_model}/{experiment_id}/{member_id}/{downscaling_model}/v1-r1-ACS-QME-AGCD-1960-2022/day/{variable_id}/{variable_id}_AGCD-05i_{parent_model}_{experiment_id}_{member_id}_{institution_id}_{downscaling_model}_v1-r1-ACS-QME-AGCD-1960-2022_day_{year}0101-{year}1231.nc" 
                 for year in np.arange(2014,2015,1)]
experiment_id = "ssp370"
filelist_ssp370 = [f"{common_dir}/{institution_id}/{parent_model}/{experiment_id}/{member_id}/{downscaling_model}/v1-r1-ACS-QME-AGCD-1960-2022/day/{variable_id}/{variable_id}_AGCD-05i_{parent_model}_{experiment_id}_{member_id}_{institution_id}_{downscaling_model}_v1-r1-ACS-QME-AGCD-1960-2022_day_{year}0101-{year}1231.nc" 
                   for year in np.arange(2015,2016,1)]

filelist = filelist_hist + filelist_ssp370

ds = xr.open_dataset(filelist[0])

mask = regions.mask_3D_frac_approx(ds)

lat_weights = np.cos(np.deg2rad(ds["lat"]))

def _preprocess(ds, mask):
    return ds.weighted(mask * lat_weights)\
                          .mean(["lat", "lon"])
    
ds_mf = xr.open_mfdataset(filelist, preprocess=lambda ds: _preprocess(ds[variable_id], mask))
ds_mf = ds_mf.compute()
ds_mf

# %%
# %%time

region_idx = 0

PATH = "/g/data/ia39/aus-ref-clim-data-nci/shapefiles/data"
name = "aus_local_gov"
gdf = gpd.read_file(f"{PATH}/{name}/{name}.shp")
max_bounds = gdf["geometry"][region_idx].bounds
regions = regionmask.from_geopandas(gdf.iloc[region_idx:region_idx+1], names ="LGA_NAME22", abbrevs="LGA_CODE22", name=name, overlap=True)

variable_id = "tasmaxAdjust"

institution_id = "BOM"
parent_model = "ACCESS-CM2"
downscaling_model = "BARPA-R"
member_id = "r4i1p1f1"

common_dir = f"/g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-output/AGCD-05i"

experiment_id = "historical"
filelist_hist = [f"{common_dir}/{institution_id}/{parent_model}/{experiment_id}/{member_id}/{downscaling_model}/v1-r1-ACS-QME-AGCD-1960-2022/day/{variable_id}/{variable_id}_AGCD-05i_{parent_model}_{experiment_id}_{member_id}_{institution_id}_{downscaling_model}_v1-r1-ACS-QME-AGCD-1960-2022_day_{year}0101-{year}1231.nc" 
                 for year in np.arange(2012,2015,1)]
experiment_id = "ssp370"
filelist_ssp370 = [f"{common_dir}/{institution_id}/{parent_model}/{experiment_id}/{member_id}/{downscaling_model}/v1-r1-ACS-QME-AGCD-1960-2022/day/{variable_id}/{variable_id}_AGCD-05i_{parent_model}_{experiment_id}_{member_id}_{institution_id}_{downscaling_model}_v1-r1-ACS-QME-AGCD-1960-2022_day_{year}0101-{year}1231.nc" 
                   for year in np.arange(2015,2018,1)]

filelist = filelist_hist + filelist_ssp370

mask = regions.mask_3D_frac_approx(xr.open_dataset(filelist[0]).sel(lat = slice(max_bounds[1], max_bounds[3]),lon = slice(max_bounds[0], max_bounds[2])))\
              .sel(region=region_idx)

def _preprocess(ds, max_bounds, mask):
    return ds.sel(lat = slice(max_bounds[1], max_bounds[3]),lon = slice(max_bounds[0], max_bounds[2]))\
                          .chunk(chunks={"time":-1, "lat": -1, "lon":-1})\
                          .where(mask)\
                          .mean(["lat", "lon"])
    
ds_mf = xr.open_mfdataset(filelist, preprocess=lambda ds: _preprocess(ds[variable_id], max_bounds, mask))
ds_mf_bounds = ds_mf.compute()
# Out:
# CPU times: user 49.5 s, sys: 3.62 s, total: 53.1 s
# Wall time: 1min 17s

# %%
ds_mf_bounds
# Out:
# <xarray.Dataset> Size: 26kB
# Dimensions:       (time: 2192)
# Coordinates:
#   * time          (time) datetime64[ns] 18kB 2012-01-01T12:00:00 ... 2017-12-...
#     region        int64 8B 0
#     abbrevs       <U5 20B '10050'
#     names         <U6 24B 'Albury'
# Data variables:
#     tasmaxAdjust  (time) float32 9kB 28.79 23.06 25.49 29.7 ... 40.2 36.4 40.08

# %%
# %%time

region_idx = 0

PATH = "/g/data/ia39/aus-ref-clim-data-nci/shapefiles/data"
name = "aus_local_gov"
gdf = gpd.read_file(f"{PATH}/{name}/{name}.shp")
max_bounds = gdf["geometry"][region_idx].bounds
regions = regionmask.from_geopandas(gdf.iloc[region_idx:region_idx+1], names ="LGA_NAME22", abbrevs="LGA_CODE22", name=name, overlap=True)

variable_id = "tasmaxAdjust"

institution_id = "BOM"
parent_model = "ACCESS-CM2"
downscaling_model = "BARPA-R"
member_id = "r4i1p1f1"

common_dir = f"/g/data/ia39/australian-climate-service/test-data/CORDEX-CMIP6/bias-adjustment-output/AGCD-05i"

experiment_id = "historical"
filelist_hist = [f"{common_dir}/{institution_id}/{parent_model}/{experiment_id}/{member_id}/{downscaling_model}/v1-r1-ACS-QME-AGCD-1960-2022/day/{variable_id}/{variable_id}_AGCD-05i_{parent_model}_{experiment_id}_{member_id}_{institution_id}_{downscaling_model}_v1-r1-ACS-QME-AGCD-1960-2022_day_{year}0101-{year}1231.nc" 
                 for year in np.arange(2012,2015,1)]
experiment_id = "ssp370"
filelist_ssp370 = [f"{common_dir}/{institution_id}/{parent_model}/{experiment_id}/{member_id}/{downscaling_model}/v1-r1-ACS-QME-AGCD-1960-2022/day/{variable_id}/{variable_id}_AGCD-05i_{parent_model}_{experiment_id}_{member_id}_{institution_id}_{downscaling_model}_v1-r1-ACS-QME-AGCD-1960-2022_day_{year}0101-{year}1231.nc" 
                   for year in np.arange(2015,2018,1)]

filelist = filelist_hist + filelist_ssp370

ds = xr.open_dataset(filelist[0])

mask = regions.mask_3D_frac_approx(ds.sel(lat = slice(max_bounds[1], max_bounds[3]),lon = slice(max_bounds[0], max_bounds[2])))\
              .sel(region=region_idx)

lat_weights = np.cos(np.deg2rad(ds["lat"]))

def _preprocess(ds, mask):
    return ds.weighted(mask * lat_weights)\
                          .mean(["lat", "lon"])
    
ds_mf = xr.open_mfdataset(filelist, preprocess=lambda ds: _preprocess(ds[variable_id], mask))
ds_mf = ds_mf.compute()
ds_mf
# Out:
# KeyboardInterrupt

# %%
ds = xr.open_dataset(filelist[0])
ds
# Out:
# <xarray.Dataset> Size: 896MB
# Dimensions:       (time: 366, lat: 691, lon: 886, bnds: 2)
# Coordinates:
#   * time          (time) datetime64[ns] 3kB 2012-01-01T12:00:00 ... 2012-12-3...
#   * lat           (lat) float64 6kB -44.5 -44.45 -44.4 ... -10.1 -10.05 -10.0
#   * lon           (lon) float64 7kB 112.0 112.0 112.1 ... 156.2 156.2 156.2
# Dimensions without coordinates: bnds
# Data variables:
#     tasmaxAdjust  (time, lat, lon) float32 896MB ...
#     lat_bnds      (lat, bnds) float64 11kB ...
#     lon_bnds      (lon, bnds) float64 14kB ...
#     time_bnds     (time, bnds) datetime64[ns] 6kB ...
# Attributes: (12/75)
#     Conventions:                               CF-1.10, ACDD-1.3
#     activity_id:                               RCM
#     title:                                     Bias-adjusted model output
#     source:                                    historical run using CSIRO-ARC...
#     project:                                   BARPA
#     program:                                   Australian Climate Service (ACS)
#     ...                                        ...
#     bc_observation:                            Australian Gridded Climate Dat...
#     bc_observation_id:                         AGCD
#     bc_period:                                 1960-2022
#     bc_info:                                   ACS-QME-AGCD-1960-2022
#     bc_code:                                   https://github.com/AusClimateS...
#     creation_date:                             2024-06-23T20:29:01Z

# %%
ds
# Out:
# <xarray.Dataset> Size: 896MB
# Dimensions:       (time: 366, lat: 691, lon: 886, bnds: 2)
# Coordinates:
#   * time          (time) datetime64[ns] 3kB 2012-01-01T12:00:00 ... 2012-12-3...
#   * lat           (lat) float64 6kB -44.5 -44.45 -44.4 ... -10.1 -10.05 -10.0
#   * lon           (lon) float64 7kB 112.0 112.0 112.1 ... 156.2 156.2 156.2
# Dimensions without coordinates: bnds
# Data variables:
#     tasmaxAdjust  (time, lat, lon) float32 896MB nan nan nan nan ... nan nan nan
#     lat_bnds      (lat, bnds) float64 11kB -44.52 -44.48 ... -10.03 -9.975
#     lon_bnds      (lon, bnds) float64 14kB 112.0 112.0 112.0 ... 156.2 156.3
#     time_bnds     (time, bnds) datetime64[ns] 6kB ...
# Attributes: (12/75)
#     Conventions:                               CF-1.10, ACDD-1.3
#     activity_id:                               RCM
#     title:                                     Bias-adjusted model output
#     source:                                    historical run using CSIRO-ARC...
#     project:                                   BARPA
#     program:                                   Australian Climate Service (ACS)
#     ...                                        ...
#     bc_observation:                            Australian Gridded Climate Dat...
#     bc_observation_id:                         AGCD
#     bc_period:                                 1960-2022
#     bc_info:                                   ACS-QME-AGCD-1960-2022
#     bc_code:                                   https://github.com/AusClimateS...
#     creation_date:                             2024-06-23T20:29:01Z

# %%
# %%time
var="tasmaxAdjust"
# calculate weights due to latitude
lat_weights = np.cos(np.deg2rad(ds["lat"]))

spatial_means = ds[var].weighted(mask_all * lat_weights).mean(dim=("lat", "lon"))

# %%
ds_mf
# Out:
# <xarray.Dataset> Size: 26kB
# Dimensions:       (time: 2192)
# Coordinates:
#   * time          (time) datetime64[ns] 18kB 2012-01-01T12:00:00 ... 2017-12-...
#     region        int64 8B 0
#     abbrevs       <U5 20B '10050'
#     names         <U6 24B 'Albury'
# Data variables:
#     tasmaxAdjust  (time) float32 9kB 28.79 23.06 25.49 29.7 ... 40.2 36.4 40.08

# %%
mask
# Out:
# <xarray.DataArray 'mask' (lat: 4, lon: 5)> Size: 160B
# array([[0.13, 0.41, 0.45, 0.33, 0.44],
#        [0.98, 1.  , 1.  , 1.  , 0.94],
#        [0.1 , 0.38, 0.85, 1.  , 0.88],
#        [0.  , 0.  , 0.58, 0.99, 0.39]])
# Coordinates:
#   * lat      (lat) float64 32B -36.1 -36.05 -36.0 -35.95
#   * lon      (lon) float64 40B 146.8 146.9 146.9 147.0 147.1
#     region   int64 8B 0
#     abbrevs  <U5 20B '10050'
#     names    <U6 24B 'Albury'
# Attributes:
#     standard_name:  region

# %%
regions = regionmask.from_geopandas(gdf, names ="LGA_NAME22", abbrevs="LGA_CODE22", name=name, overlap=True)
regions
# Out:
# <regionmask.Regions 'aus_local_gov'>
# overlap:  True
#
# Regions:
#   0 10050                      Albury
#   1 10180                    Armidale
#   2 10250                     Ballina
#   3 10300                   Balranald
#   4 10470                    Bathurst
#  ..   ...                         ...
# 542 74660                 West Arnhem
# 543 74680                   West Daly
# 544 79399           Unincorporated NT
# 545 89399          Unincorporated ACT
# 546 99399 Unincorp. Other Territories
#
# [547 regions]

# %%
ds = xr.open_dataset(filelist[0])
ds
# Out:
# <xarray.Dataset> Size: 896MB
# Dimensions:       (time: 366, lat: 691, lon: 886, bnds: 2)
# Coordinates:
#   * time          (time) datetime64[ns] 3kB 2012-01-01T12:00:00 ... 2012-12-3...
#   * lat           (lat) float64 6kB -44.5 -44.45 -44.4 ... -10.1 -10.05 -10.0
#   * lon           (lon) float64 7kB 112.0 112.0 112.1 ... 156.2 156.2 156.2
# Dimensions without coordinates: bnds
# Data variables:
#     tasmaxAdjust  (time, lat, lon) float32 896MB ...
#     lat_bnds      (lat, bnds) float64 11kB ...
#     lon_bnds      (lon, bnds) float64 14kB ...
#     time_bnds     (time, bnds) datetime64[ns] 6kB ...
# Attributes: (12/75)
#     Conventions:                               CF-1.10, ACDD-1.3
#     activity_id:                               RCM
#     title:                                     Bias-adjusted model output
#     source:                                    historical run using CSIRO-ARC...
#     project:                                   BARPA
#     program:                                   Australian Climate Service (ACS)
#     ...                                        ...
#     bc_observation:                            Australian Gridded Climate Dat...
#     bc_observation_id:                         AGCD
#     bc_period:                                 1960-2022
#     bc_info:                                   ACS-QME-AGCD-1960-2022
#     bc_code:                                   https://github.com/AusClimateS...
#     creation_date:                             2024-06-23T20:29:01Z

# %%
# %%time
mask_all = regions.mask_3D(ds)
mask_all
# Out:
# CPU times: user 5.32 s, sys: 312 ms, total: 5.63 s
# Wall time: 5.65 s
# <xarray.DataArray 'mask' (region: 518, lat: 691, lon: 886)> Size: 317MB
# array([[[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]],
#
#        [[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]],
#
#        [[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
# ...
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]],
#
#        [[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]],
#
#        [[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]]])
# Coordinates:
#   * lat      (lat) float64 6kB -44.5 -44.45 -44.4 -44.35 ... -10.1 -10.05 -10.0
#   * lon      (lon) float64 7kB 112.0 112.0 112.1 112.2 ... 156.2 156.2 156.2
#   * region   (region) int64 4kB 0 1 2 3 4 5 6 7 ... 539 540 542 543 544 545 546
#     abbrevs  (region) <U5 10kB '10050' '10180' '10250' ... '89399' '99399'
#     names    (region) <U37 77kB 'Albury' ... 'Unincorp. Other Territories'
# Attributes:
#     standard_name:  region

# %%
# %%time
var="tasmaxAdjust"
# calculate weights due to latitude
lat_weights = np.cos(np.deg2rad(ds["lat"]))

spatial_means = ds[var].weighted(mask_all * lat_weights).mean(dim=("lat", "lon"))
# Out:
# CPU times: user 12.1 s, sys: 1.7 s, total: 13.8 s
# Wall time: 13.8 s

# %%
spatial_means
# Out:
# <xarray.DataArray 'tasmaxAdjust' (time: 366, region: 518)> Size: 2MB
# array([[28.77797331, 27.65398449, 31.85469359, ..., 33.92703066,
#         19.05175612, 19.55078125],
#        [22.97652406, 18.60662782, 22.89122493, ..., 33.44623015,
#         16.51616511, 18.12304688],
#        [25.3951162 , 17.01561278, 21.83996981, ..., 34.25835203,
#         19.00262314, 18.78125   ],
#        ...,
#        [21.71800448, 22.80279986, 28.08374235, ..., 32.19602949,
#         17.79576239, 23.5078125 ],
#        [26.42639925, 24.92095604, 30.27447863, ..., 35.24520112,
#         21.39564249, 27.79296875],
#        [26.10410685, 26.28627587, 31.04390528, ..., 34.29985735,
#         24.33969061, 19.16210938]])
# Coordinates:
#   * time     (time) datetime64[ns] 3kB 2012-01-01T12:00:00 ... 2012-12-31T12:...
#   * region   (region) int64 4kB 0 1 2 3 4 5 6 7 ... 539 540 542 543 544 545 546
#     abbrevs  (region) <U5 10kB '10050' '10180' '10250' ... '89399' '99399'
#     names    (region) <U37 77kB 'Albury' ... 'Unincorp. Other Territories'

# %%
# %%time

ts_lga0 = ds.where(mask.sel(region = 0))[var].mean(["lat", "lon"]).compute()
ts_lga0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <timed exec>:2
#
# NameError: name 'ds' is not defined

# %%
# %%time
# Fractional masking does not work unless the lat lons are a regular grid. 
# frac_mask = regions.mask_3D_frac_approx(ds)
# Out:
# CPU times: user 3 μs, sys: 1e+03 ns, total: 4 μs
# Wall time: 6.44 μs

# %%
# %%time
ts_lga0 = ds.where(mask.sel(region = 0)).pr.mean(["lat", "lon"]).compute()
ts_lga0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <timed exec>:1
#
# NameError: name 'ds' is not defined

# %%
mask.sel(region=0).total_bounds
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 mask.sel(region=0).total_bounds
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/xarray/core/dataarray.py:1644, in DataArray.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    1528 def sel(
#    1529     self,
#    1530     indexers: Mapping[Any, Any] | None = None,
#    (...)
#    1534     **indexers_kwargs: Any,
#    1535 ) -> Self:
#    1536     """Return a new DataArray whose data is given by selecting index
#    1537     labels along the specified dimension(s).
#    1538
#    (...)
#    1642     Dimensions without coordinates: points
#    1643     """
# -> 1644     ds = self._to_temp_dataset().sel(
#    1645         indexers=indexers,
#    1646         drop=drop,
#    1647         method=method,
#    1648         tolerance=tolerance,
#    1649         **indexers_kwargs,
#    1650     )
#    1651     return self._from_temp_dataset(ds)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/xarray/core/dataset.py:3126, in Dataset.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    3058 """Returns a new dataset with each array indexed by tick labels
#    3059 along the specified dimension(s).
#    3060
#    (...)
#    3123
#    3124 """
#    3125 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "sel")
# -> 3126 query_results = map_index_queries(
#    3127     self, indexers=indexers, method=method, tolerance=tolerance
#    3128 )
#    3130 if drop:
#    3131     no_scalar_variables = {}
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/xarray/core/indexing.py:184, in map_index_queries(obj, indexers, method, tolerance, **indexers_kwargs)
#     181     options = {"method": method, "tolerance": tolerance}
#     183 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "map_index_queries")
# --> 184 grouped_indexers = group_indexers_by_index(obj, indexers, options)
#     186 results = []
#     187 for index, labels in grouped_indexers:
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/xarray/core/indexing.py:143, in group_indexers_by_index(obj, indexers, options)
#     141     grouped_indexers[index_id][key] = label
#     142 elif key in obj.coords:
# --> 143     raise KeyError(f"no index found for coordinate {key!r}")
#     144 elif key not in obj.dims:
#     145     raise KeyError(
#     146         f"{key!r} is not a valid dimension or coordinate for "
#     147         f"{obj.__class__.__name__} with dimensions {obj.dims!r}"
#     148     )
#
# KeyError: "no index found for coordinate 'region'"

# %%
ts_lga0.plot()

# %%
import ee

# %%
# %%time
ds.where(mask.sel(region = 0)).pr.max().compute()

# %%
# %%time
# Apply the mask and calculate regional means for all timesteps
var = "pr"
da_means = acs_regional_stats(ds, var=var, dims=("lat", "lon"), mask = mask, how = ["mean"], select_abbr="WANorth")
da_means

# %%
# Plot the timeseries of one of the regions
da_means.sel(region = 0)
