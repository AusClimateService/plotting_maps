# %% [markdown]
# # Plotting maps example
#
# This notebook gives a minimal example of using acs_plotting_maps.py
#
# Code is available publically here [https://github.com/AusClimateService/plotting_maps/blob/main/acs_plotting_maps.py]
#
# The README [https://github.com/AusClimateService/plotting_maps/tree/main] gives cloning instructions and virtual environment requirements to ensure it runs smoothly.
#
# For example, in your working directory (eg navigate to your home, scratch, or user directory in a project using cd), clone this repository to access this code
# ```
# $ git clone https://github.com/AusClimateService/plotting_maps.git plotting_maps
# ```
#
# This code is designed to work with hh5 analysis3-24.04 virtual environment. Eg:
# ```
# $ module use /g/data/hh5/public/modules
# $ module load conda_concept/analysis3-24.04
# ```

# %% [markdown]
# # Step 1 - access plotting package
# Navigate to the directory that you have cloned the plotting_maps repo to. eg
# ```
# cd ~/plotting_maps
# ```

# %%
cd /g/data/mn51/users/gt3409/plotting_maps/
# Out:
# /g/data/mn51/users/gt3409/plotting_maps

# %% [markdown]
# Then import the plotting function ```plot_acs_hazard``` and helpful dictionaries ```regions_dict, cmap_dict, tick_dict```

# %%
# import ACS plotting maps and Xarray.
from acs_plotting_maps import plot_acs_hazard, regions_dict, cmap_dict, tick_dict
import xarray as xr
import pandas as pd
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import numpy as np

# %%
# step 2 - read and prepare data
# step 3 - plot

# %%
df = pd.read_csv("/g/data/ia39/ncra/coastal/flood_days/annmax_exceeds_means.csv")

# %%
df
# Out:
#               site        lat         lon  0.0m 10th percentile  \
# 0           Albany -35.033700  117.892600              0.166667
# 1          Ballina -28.875377  153.584429              0.333333
# 2     Booby Island -10.602600  141.910100              0.000000
# 3         Brisbane -27.360800  153.171900              0.166667
# 4           Broome -18.000800  122.218600              2.666667
# 5          Bunbury -33.323400  115.660000              0.000000
# 6        Bundaberg -24.766700  152.383300              0.333333
# 7           Burnie -41.052800  145.911100              1.000000
# 8           Cairns -16.926700  145.780000              0.000000
# 9        Carnarvon -24.898700  113.651000              0.000000
# 10          Darwin -12.471800  130.845900              2.166667
# 11            Eden -37.071200  149.908300              0.316667
# 12       Esperance -33.870900  121.895400              0.333333
# 13       Fremantle -32.055800  115.739500              0.166667
# 14         Geelong -38.146700  144.363300              0.333333
# 15       Geraldton -28.776000  114.601900              0.000000
# 16       Gladstone -23.833300  151.250000              0.333333
# 17      Gold Coast -27.966700  153.416700              0.333333
# 18          Hobart -42.877300  147.341000              0.333333
# 19  Lakes Entrance -37.889200  147.972800              0.500000
# 20          Mackay -21.116700  149.233300              0.000000
# 21       Melbourne -37.865700  144.916500              0.333333
# 22       Newcastle -32.923800  151.788900              0.333333
# 23          Onslow -21.649700  115.131500              1.333333
# 24  Point Lonsdale -38.291900  144.613900              0.333333
# 25    Port Hedland -20.317600  118.574400              1.000000
# 26     Port Kembla -34.475000  150.910000              0.166667
# 27    Port Lincoln -34.715900  135.870100              0.000000
# 28      Port Pirie -33.177600  138.011700              0.666667
# 29        Portland -38.351400  141.619700              0.333333
# 30       Thevenard -32.148900  133.641300              0.166667
# 31      Townsville -19.250000  146.833300              0.000000
# 32   Victor Harbor -35.562500  138.635400              0.000000
# 33           Weipa -12.670000  141.863300              0.000000
# 34         Wyndham -15.453300  128.101000              4.166667
# 35        National        NaN         NaN              0.523333
#
#     0.0m 50th percentile  0.0m 90th percentile  0.06m 10th percentile  \
# 0               1.500000              6.000000               0.166667
# 1               2.333333              5.000000               0.500000
# 2               0.000000              1.500000               0.000000
# 3               1.333333              3.500000               0.833333
# 4               4.500000              7.166667               1.666667
# 5               1.000000              3.000000               0.000000
# 6               1.500000              3.350000               0.833333
# 7               3.333333              6.000000               1.333333
# 8               1.000000              2.666667               0.166667
# 9               1.333333              6.166667               0.000000
# 10              5.666667              9.500000               2.333333
# 11              1.500000              3.666667               0.483333
# 12              2.000000              4.833333               0.333333
# 13              1.666667              5.516667               0.166667
# 14              1.666667              4.333333               0.333333
# 15              1.333333              4.833333               0.000000
# 16              1.500000              3.500000               0.500000
# 17              1.666667              3.833333               0.666667
# 18              1.500000              4.000000               0.833333
# 19              2.500000              5.500000               1.000000
# 20              0.333333              1.833333               0.000000
# 21              1.666667              4.000000               0.333333
# 22              1.500000              4.833333               0.833333
# 23              4.500000             10.000000               1.500000
# 24              2.333333              5.333333               0.333333
# 25              3.000000              6.000000               1.000000
# 26              1.333333              3.500000               0.666667
# 27              1.333333              3.000000               0.000000
# 28              2.333333              4.833333               1.000000
# 29              1.833333              4.166667               0.333333
# 30              1.666667              3.833333               0.166667
# 31              0.666667              2.333333               0.000000
# 32              1.333333              3.833333               0.000000
# 33              0.333333              1.333333               0.000000
# 34             10.166667             19.500000               5.166667
# 35              2.090476              4.920000               0.670952
#
#     0.06m 50th percentile  0.06m 90th percentile  0.1m 10th percentile  ...  \
# 0                2.333333               7.500000              1.000000  ...
# 1                3.166667               6.666667              2.333333  ...
# 2                0.500000               2.166667              0.000000  ...
# 3                2.833333               5.500000              2.333333  ...
# 4                3.000000               5.333333              1.166667  ...
# 5                1.166667               3.333333              0.000000  ...
# 6                2.666667               5.016667              0.833333  ...
# 7                4.166667               7.500000              2.333333  ...
# 8                1.500000               3.666667              0.833333  ...
# 9                1.500000               7.666667              0.000000  ...
# 10               5.333333               8.833333              2.500000  ...
# 11               2.666667               5.500000              1.333333  ...
# 12               2.333333               5.833333              1.000000  ...
# 13               2.333333               6.366667              0.333333  ...
# 14               2.333333               5.500000              1.000000  ...
# 15               1.833333               6.000000              0.166667  ...
# 16               1.666667               4.166667              1.000000  ...
# 17               2.666667               5.500000              2.833333  ...
# 18               2.833333               6.000000              1.500000  ...
# 19               3.500000               6.833333              1.650000  ...
# 20               0.500000               1.666667              0.666667  ...
# 21               2.333333               5.333333              1.000000  ...
# 22               2.833333               6.833333              1.500000  ...
# 23               4.833333              11.000000              2.000000  ...
# 24               2.833333               6.666667              1.000000  ...
# 25               3.000000               5.666667              0.833333  ...
# 26               2.666667               5.666667              2.333333  ...
# 27               1.500000               4.000000              0.166667  ...
# 28               3.000000               5.166667              1.000000  ...
# 29               2.333333               5.500000              1.000000  ...
# 30               2.000000               4.333333              0.983333  ...
# 31               0.666667               2.500000              0.166667  ...
# 32               1.333333               4.166667              0.000000  ...
# 33               0.666667               2.000000              0.000000  ...
# 34              10.333333              17.833333              6.333333  ...
# 35               2.604762               5.806190              1.232381  ...
#
#     0.2m 90th percentile  0.38m 10th percentile  0.38m 50th percentile  \
# 0              31.333333              49.500000              67.166667
# 1              33.500000              70.483333              95.833333
# 2               9.666667              11.600000              18.700000
# 3              25.850000              69.166667              81.666667
# 4              11.166667               9.000000              13.250000
# 5              11.166667              14.166667              24.916667
# 6              20.333333              37.500000              46.000000
# 7              26.166667              67.483333              84.416667
# 8              11.833333              25.333333              33.500000
# 9              32.666667              34.650000              63.333333
# 10             17.333333              20.000000              27.916667
# 11             23.166667              55.666667              78.833333
# 12             22.000000              41.150000              59.250000
# 13             23.533333              33.333333              50.000000
# 14             23.516667              59.816667              99.250000
# 15             23.000000              32.500000              56.416667
# 16             18.166667              33.166667              40.333333
# 17             31.833333              85.316667             103.166667
# 18             24.333333              57.666667              80.416667
# 19             26.500000              63.500000             101.000000
# 20              8.833333              14.333333              18.333333
# 21             20.666667              53.333333              72.166667
# 22             33.366667              77.333333              96.333333
# 23             32.666667              42.500000              66.500000
# 24             26.666667              53.150000              79.666667
# 25             10.000000              12.333333              19.166667
# 26             26.016667              74.833333              87.833333
# 27             10.333333              15.650000              25.833333
# 28              9.500000              10.150000              16.000000
# 29             22.666667              58.133333              79.833333
# 30              8.500000              10.500000              16.666667
# 31              8.000000              13.833333              18.500000
# 32              8.500000              11.150000              18.500000
# 33              4.833333               4.833333              10.666667
# 34             39.500000              36.316667              51.000000
# 35             20.489048              38.839524              54.353333
#
#     0.38m 90th percentile  0.6m 10th percentile  0.6m 50th percentile  \
# 0              120.366667            192.116667            218.833333
# 1              122.666667            218.333333            250.083333
# 2               29.800000             43.000000             55.500000
# 3               98.166667            192.833333            209.500000
# 4               18.500000             24.400000             29.400000
# 5               52.833333             90.000000            121.800000
# 6               56.666667            111.333333            125.166667
# 7              102.666667            209.180000            231.800000
# 8               43.516667             76.666667             88.583333
# 9              125.850000            160.800000            211.300000
# 10              35.166667             46.400000             58.000000
# 11              97.366667            196.483333            231.166667
# 12              88.166667            160.483333            190.500000
# 13             103.000000            157.000000            189.300000
# 14             124.850000            257.180000            302.300000
# 15             105.016667            162.580000            207.800000
# 16              52.166667             84.833333             94.750000
# 17             119.833333            238.833333            258.000000
# 18             106.050000            217.633333            251.166667
# 19             121.500000            258.816667            301.000000
# 20              24.166667             39.000000             44.500000
# 21              96.366667            233.180000            263.600000
# 22             129.683333            235.816667            258.666667
# 23              99.500000            132.380000            162.800000
# 24             115.366667            201.400000            236.200000
# 25              28.183333             38.000000             49.800000
# 26             107.833333            230.500000            247.166667
# 27              38.666667             73.400000             99.400000
# 28              22.166667             34.975000             47.000000
# 29             102.666667            206.400000            237.500000
# 30              25.016667             44.980000             60.000000
# 31              27.000000             45.633333             52.833333
# 32              27.333333             53.333333             72.166667
# 33              19.333333             29.380000             45.200000
# 34              70.850000             82.600000            101.400000
# 35              75.950952            136.568143            160.119524
#
#     0.6m 90th percentile  1.0m 10th percentile  1.0m 50th percentile  \
# 0             282.500000            362.250000            364.250000
# 1             277.850000            363.750000            365.250000
# 2              72.750000            155.000000            176.000000
# 3             228.350000            356.000000            359.500000
# 4              35.600000             63.750000             72.875000
# 5             189.820000            341.000000            353.250000
# 6             141.016667            280.000000            292.250000
# 7             253.600000            362.750000            364.500000
# 8             103.350000            237.750000            252.250000
# 9             279.400000            352.000000            359.500000
# 10             67.400000            116.000000            133.750000
# 11            255.016667            364.000000            365.500000
# 12            231.016667            356.000000            361.000000
# 13            267.020000            359.750000            363.500000
# 14            322.400000            365.000000            365.000000
# 15            271.020000            358.250000            362.500000
# 16            113.500000            223.250000            232.500000
# 17            274.850000            365.000000            365.250000
# 18            280.200000            364.500000            365.250000
# 19            317.166667            365.250000            365.250000
# 20             52.166667            114.500000            124.000000
# 21            294.040000            365.500000            365.500000
# 22            290.716667            365.500000            365.500000
# 23            202.640000            306.750000            325.000000
# 24            274.220000            363.500000            365.500000
# 25             64.220000            113.500000            127.750000
# 26            271.016667            365.250000            365.250000
# 27            123.820000            261.250000            284.750000
# 28             58.750000            151.725000            172.500000
# 29            265.000000            364.000000            365.250000
# 30             78.200000            201.250000            222.625000
# 31             65.666667            161.750000            172.750000
# 32             93.683333            254.475000            280.750000
# 33             63.800000            145.000000            170.000000
# 34            125.620000            182.725000            199.750000
# 35            188.211048            280.797857            289.885714
#
#     1.0m 90th percentile
# 0             365.250000
# 1             365.250000
# 2             209.700000
# 3             362.500000
# 4              83.250000
# 5             363.000000
# 6             305.500000
# 7             365.750000
# 8             269.050000
# 9             364.250000
# 10            146.000000
# 11            365.500000
# 12            364.750000
# 13            365.250000
# 14            365.000000
# 15            365.000000
# 16            248.525000
# 17            365.250000
# 18            365.250000
# 19            365.250000
# 20            138.000000
# 21            365.500000
# 22            365.500000
# 23            340.500000
# 24            365.500000
# 25            142.525000
# 26            365.250000
# 27            304.275000
# 28            190.500000
# 29            365.250000
# 30            242.275000
# 31            193.500000
# 32            303.000000
# 33            193.250000
# 34            217.250000
# 35            298.895714
#
# [36 rows x 24 columns]

# %%
var = "0.06m 90th percentile"

plot_acs_hazard(station_df=df[["lat", "lon", var]],
                regions = regions_dict['ncra_regions'],
                cmap=cm.viridis_r,
                ticks=np.arange(0,18,3),
                cbar_extend="max",
                title = "Annual exceedances of minor impact level",
                date_range = "0.06m",
                cbar_label = "annual exceedances [days]",
                dataset_name = "BARPA-R ACCESS-CM2",
               facecolor="lightgrey");

# %%
# another example starting with a netcdf

# %%
# read in netcdf
ds = xr.open_dataset("/g/data/ia39/ncra/coastal/MSL/sl_projection_anchors_ssp370.nc")

# select and arrange data into dataframe with columns ["lat", "lon", var]
df = ds.sel(PERCENTILE=50, TYEAR=2020)[["LONX", "LATY", "SL1"]].to_dataframe()[["LONX", "LATY", "SL1"]]
df = df.rename(columns = {"LONX": "lon", "LATY": "lat"})

var = "SL1"

plot_acs_hazard(station_df=df[["lat", "lon", var]],
                regions = regions_dict['ncra_regions'],
                cmap=cm.viridis_r,
                ticks=np.arange(0.04,0.06,0.002),
                cbar_extend="max",
                title = "",
                date_range = "",
                cbar_label = "",
                dataset_name = "",);
